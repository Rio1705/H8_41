# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statistics
import scipy
import scipy.stats
import statsmodels.api as sm
from IPython.display import Math, Latex
from IPython.core.display import Image
from scipy.stats import uniform, norm, gamma, expon, poisson, binom, bernoulli, shapiro, normaltest
from statsmodels.stats import weightstats as wmtests

#seaborn config
#sns.set(color_codes=True)
#sns.set(rc={'figure.figsize': (5,5)})

# %%
df = pd.read_csv('nyc_rolling_sales.csv')
df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %%
df.shape
# Out:
# (84548, 22)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                        0
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
#hapus kolom Unnamed dan easement
df.drop(columns=['Unnamed: 0', 'EASE-MENT'], inplace=True)

# %%
df.shape
# Out:
# (84548, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  int64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  int64
#  5   LOT                             84548 non-null  int64
#  6   BUILDING CLASS AT PRESENT       84548 non-null  object
#  7   ADDRESS                         84548 non-null  object
#  8   APARTMENT NUMBER                84548 non-null  object
#  9   ZIP CODE                        84548 non-null  int64
#  10  RESIDENTIAL UNITS               84548 non-null  int64
#  11  COMMERCIAL UNITS                84548 non-null  int64
# ...

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 1                    2    399   26                        C7
# 2                    2    399   39                        C7
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0            153 AVENUE B                      10009                  5
# 1   234 EAST 4TH   STREET                      10009                 28
# ...

# %%
df.tail(10)
# Out:
#        BOROUGH NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 84538        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84539        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84540        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84541        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84542        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84543        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5      WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5      WOODROW  22 STORE BUILDINGS
# 84547        5      WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 84538                    1   7316   61                        B2
# 84539                    1   7316   85                        B2
# 84540                    1   7316   93                        B2
# 84541                    1   7317  126                        B2
# ...

# %%
print('Column name')
for col in df.columns:
    if df[col].dtype=='object':
        print(col, df[col].nunique())
# Out:
# Column name
# NEIGHBORHOOD 254
# BUILDING CLASS CATEGORY 47
# TAX CLASS AT PRESENT 11
# BUILDING CLASS AT PRESENT 167
# ADDRESS 67563
# APARTMENT NUMBER 3989
# LAND SQUARE FEET 6062
# GROSS SQUARE FEET 5691
# BUILDING CLASS AT TIME OF SALE 166
# SALE PRICE 10008
# SALE DATE 364

# %%
numer = ['LAND SQUARE FEET','GROSS SQUARE FEET', 'SALE PRICE', 'BOROUGH']
for col in numer: # coerce for missing values
    df[col] = pd.to_numeric(df[col], errors='coerce')

categ = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BUILDING CLASS AT PRESENT', 'BUILDING CLASS AT TIME OF SALE', 'TAX CLASS AT TIME OF SALE']
for col in categ:
    df[col] = df[col].astype('category')

df['SALE DATE'] = pd.to_datetime(df['SALE DATE'], errors='coerce')

# %%
missing = df.isnull().sum()/len(df)*100

print(pd.DataFrame([missing[missing>0],pd.Series(df.isnull().sum()[df.isnull().sum()>1000])], index=['percent missing','how many missing']))
# Out:
#                   LAND SQUARE FEET  GROSS SQUARE FEET   SALE PRICE
# percent missing          31.049818          32.658372     17.22217
# how many missing      26252.000000       27612.000000  14561.00000

# %%
print(df[(df['LAND SQUARE FEET'].isnull()) & (df['GROSS SQUARE FEET'].notnull())].shape)
print(df[(df['LAND SQUARE FEET'].notnull()) & (df['GROSS SQUARE FEET'].isnull())].shape)
# Out:
# (6, 20)
# (1366, 20)

# %%
df['LAND SQUARE FEET'] = df['LAND SQUARE FEET'].mask((df['LAND SQUARE FEET'].isnull()) & (df['GROSS SQUARE FEET'].notnull()), df['GROSS SQUARE FEET'])
df['GROSS SQUARE FEET'] = df['GROSS SQUARE FEET'].mask((df['LAND SQUARE FEET'].notnull()) & (df['GROSS SQUARE FEET'].isnull()), df['LAND SQUARE FEET'])

# %%
df.head(20)
# Out:
#     BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 5         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 7         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 8         1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 9         1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 10        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 11        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 12        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 13        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 14        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# ...

# %%
print(sum(df.duplicated()))

df[df.duplicated(keep=False)].sort_values(['NEIGHBORHOOD', 'ADDRESS']).head(10)
# Out:
# 765
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 76286        5       ANNADALE  02 TWO FAMILY DWELLINGS
# 76287        5       ANNADALE  02 TWO FAMILY DWELLINGS
# 76322        5       ANNADALE  05 TAX CLASS 1 VACANT LAND
# 76323        5       ANNADALE  05 TAX CLASS 1 VACANT LAND
# 76383        5  ARDEN HEIGHTS  01 ONE FAMILY DWELLINGS
# 76384        5  ARDEN HEIGHTS  01 ONE FAMILY DWELLINGS
# 76643        5       ARROCHAR  02 TWO FAMILY DWELLINGS
# 76644        5       ARROCHAR  02 TWO FAMILY DWELLINGS
# 50126        4        ASTORIA  03 THREE FAMILY DWELLINGS
# 50127        4        ASTORIA  03 THREE FAMILY DWELLINGS
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 76286                    1   6350    7                        B2
# 76287                    1   6350    7                        B2
# 76322                   1B   6459   28                        V0
# ...

# %%
df.drop_duplicates(inplace=True)

print(sum(df.duplicated()))
# Out:
# 0

# %%
df.shape
# Out:
# (83783, 20)

# %%
df.head(20)
# Out:
#     BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 5         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 7         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 8         1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 9         1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 10        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 11        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 12        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 13        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 14        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         83783 non-null  int64
#  1   NEIGHBORHOOD                    83783 non-null  category
#  2   BUILDING CLASS CATEGORY         83783 non-null  category
#  3   TAX CLASS AT PRESENT            83783 non-null  category
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83783 non-null  category
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                83783 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26049
# GROSS SQUARE FEET                 26049
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14176
# SALE DATE                             0
# dtype: int64

# %%
df[df['COMMERCIAL UNITS']==0].describe()
# Out:
#             BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  78777.000000  78777.000000  78777.000000  78777.000000
# mean       3.004329   4273.781015    395.422420  10722.737068
# std        1.298594   3589.241940    671.604654   1318.493961
# min        1.000000      1.000000      1.000000      0.000000
# 25%        2.000000   1330.000000     23.000000  10304.000000
# 50%        3.000000   3340.000000     52.000000  11209.000000
# 75%        4.000000   6361.000000   1003.000000  11357.000000
# max        5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count       78777.000000           78777.0  78777.000000      5.278000e+04
# mean            1.691737               0.0      1.724133      3.140140e+03
# std             9.838994               0.0      9.835016      2.929999e+04
# min             0.000000               0.0      0.000000      0.000000e+00
# ...

# %%
df[df['RESIDENTIAL UNITS']>0].describe()
# Out:
#             BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  59237.000000  59237.000000  59237.000000  59237.000000
# mean       3.188767   4610.712342    414.339788  10903.841552
# std        1.219989   3686.816317    687.593893    603.316848
# min        1.000000      1.000000      1.000000      0.000000
# 25%        3.000000   1490.000000     26.000000  10312.000000
# 50%        3.000000   3937.000000     56.000000  11214.000000
# 75%        4.000000   6713.000000   1009.000000  11360.000000
# max        5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count       59237.000000      59237.000000  59237.000000      4.823100e+04
# mean            2.828705          0.069433      2.897277      3.156000e+03
# std            19.645674          0.460570     19.832720      2.814200e+04
# min             1.000000          0.000000      1.000000      0.000000e+00
# ...

# %% [markdown]
# ### Findings:
#
# - 75% of properties have no COMMERCIAL UNITS
# - At least 50% of all properties have only 1 TOTAL UNIT
# - 1844 RESIDENTIAL and 25 COMMERCIAL UNITS looks like an outlier
# - There are properties have 0 SQUARE FEET, which shouldn't be possible unless they don't exist yet or the data is wrong
# - Some properties have a SALE PRICE of 0, which is not actually a sale just like the description in template

# %%
df['BOROUGH'].value_counts()
# Out:
# 4    26548
# 3    23843
# 1    18102
# 5     8296
# 2     6994
# Name: BOROUGH, dtype: int64

# %%
#coba-coba
df.groupby(['BOROUGH'])['RESIDENTIAL UNITS'].mean()
# Out:
# BOROUGH
# 1    2.276931
# 2    3.343580
# 3    2.011618
# 4    1.687283
# 5    1.230111
# Name: RESIDENTIAL UNITS, dtype: float64

# %% [markdown]
# ## Mean, Median, and Mode for Each Borough

# %%
df.groupby(['BOROUGH']).mean()
# Out:
#                BLOCK         LOT      ZIP CODE  RESIDENTIAL UNITS  \
# BOROUGH
# 1        1107.657938  749.190421   9912.565960           2.276931
# 2        4202.934372  298.625679  10360.980841           3.343580
# 3        4317.583484  339.525228  11072.688210           2.011618
# 4        6630.747589  230.493672  11300.423572           1.687283
# 5        3261.786162  198.775554  10047.136090           1.230111
#
#          COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# BOROUGH
# 1                0.280521     2.597227       5646.945628       32622.997758
# 2                0.160280     3.510152       3909.012725        4489.147412
# 3                0.145451     2.194229       2016.057333        2481.756365
# 4                0.190410     1.908920       4265.245190        3345.841693
# 5                0.080400     1.313163       8339.843259        4709.373037
#
#           YEAR BUILT    SALE PRICE
# BOROUGH
# 1        1706.536902  3.344642e+06
# ...

# %%
df.groupby(['BOROUGH']).median()
# Out:
#           BLOCK     LOT  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# BOROUGH
# 1        1170.0  1004.0   10022.0                0.0               0.0
# 2        4177.5    47.0   10465.0                1.0               0.0
# 3        4558.0    50.0   11219.0                1.0               0.0
# 4        5900.0    40.0   11375.0                1.0               0.0
# 5        3024.0    56.0   10308.0                1.0               0.0
#
#          TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# BOROUGH
# 1                1.0            2498.0             7520.0      1937.0
# 2                1.0            2375.0             1764.0      1932.0
# 3                1.0            1800.0             1520.0      1930.0
# 4                1.0            2768.0             1728.0      1945.0
# 5                1.0            3700.0             1632.0      1973.0
#
#          SALE PRICE
# BOROUGH
# 1         1155000.0
# 2          274897.0
# 3          425605.0
# ...

# %%
df.groupby(['BOROUGH']).apply(lambda x: x.mode())
# Out:
#            BOROUGH             NEIGHBORHOOD  \
# BOROUGH
# 1       0        1  UPPER EAST SIDE (59-79)
# 2       0        2                RIVERDALE
# 3       0        3       BEDFORD STUYVESANT
# 4       0        4           FLUSHING-NORTH
# 5       0        5              GREAT KILLS
#
#                                BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# BOROUGH
# 1       0  13 CONDOS - ELEVATOR APARTMENTS                                2
# 2       0  02 TWO FAMILY DWELLINGS                                        1
# 3       0  02 TWO FAMILY DWELLINGS                                        1
# 4       0  01 ONE FAMILY DWELLINGS                                        1
# 5       0  01 ONE FAMILY DWELLINGS                                        1
#
#            BLOCK  LOT BUILDING CLASS AT PRESENT                 ADDRESS  \
# BOROUGH
# 1       0     16    1                        R4  169 WEST 95TH   STREET
# ...

# %%
#coba-coba
df.mode()
# Out:
#    BOROUGH    NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        4  FLUSHING-NORTH  01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                    1   5066    1                        D4
#
#               ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0  131-05 40TH   ROAD                      10314                  1
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                 0            1               0.0                0.0
#
#    YEAR BUILT TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 0           0                         1                             R4
#
#    SALE PRICE  SALE DATE
# 0         0.0 2017-06-29

# %%
#coba-coba
df.apply(lambda x: x.mode())
# Out:
#    BOROUGH    NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        4  FLUSHING-NORTH  01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                    1   5066    1                        D4
#
#               ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0  131-05 40TH   ROAD                      10314                  1
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                 0            1               0.0                0.0
#
#    YEAR BUILT TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 0           0                         1                             R4
#
#    SALE PRICE  SALE DATE
# 0         0.0 2017-06-29

# %% [markdown]
# ## Box Plot Bronx Price Data

# %%
bronx_data = df.loc[df['BOROUGH'] == 2]
bronx_data.head(20)
# Out:
#        BOROUGH NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 18306        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18307        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18308        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18309        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18310        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18311        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18312        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18313        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 18314        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18315        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18316        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18317        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18318        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18319        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18320        2     BATHGATE  02 TWO FAMILY DWELLINGS
# 18321        2     BATHGATE  02 TWO FAMILY DWELLINGS
# ...

# %%
bronx_price = bronx_data[['SALE PRICE']]
bronx_price
# Out:
#        SALE PRICE
# 18306    140000.0
# 18307    420000.0
# 18308    127000.0
# 18309    273796.0
# 18310    231244.0
# ...           ...
# 25350    205000.0
# 25351    117000.0
# 25352   1085250.0
# 25353         0.0
# 25354   1414750.0
#
# [6994 rows x 1 columns]

# %%
bronx_price.dropna(axis=0,inplace=True)
bronx_price
# Out:
# <ipython-input-112-36d12157321b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bronx_price.dropna(axis=0,inplace=True)
#        SALE PRICE
# 18306    140000.0
# 18307    420000.0
# 18308    127000.0
# 18309    273796.0
# 18310    231244.0
# ...           ...
# 25350    205000.0
# 25351    117000.0
# 25352   1085250.0
# 25353         0.0
# 25354   1414750.0
#
# [6994 rows x 1 columns]

# %%
bronx_price_array = np.array(bronx_price)
bronx_price_array
# Out:
# array([[ 140000.],
#        [ 420000.],
#        [ 127000.],
#        ...,
#        [1085250.],
#        [      0.],
#        [1414750.]])

# %%
fig, bx = plt.subplots()
bx.boxplot(bronx_price_array, vert=False, showmeans=True, meanline=True, labels=None, patch_artist=True,
           medianprops= {'linewidth':2, 'color':'purple'}, meanprops={'linewidth':2, 'color':'red'})
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.boxplot(bronx_price_array) 
plt.show()

# %% [markdown]
# ## Z-score Calculation

# %%
scipy.stats.zscore(bronx_price_array)
# Out:
# array([[-0.16277364],
#        [-0.06253411],
#        [-0.16742761],
#        ...,
#        [ 0.17562426],
#        [-0.2128934 ],
#        [ 0.2935847 ]])

# %% [markdown]
# ## Probability Mass Function Plot

# %%
plt.figure(figsize=(15,5))

sns.distplot(bronx_price_array, kde=True, color='r')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Confidence Interval

# %%
bronx_price_array.mean(), bronx_price_array.std(), bronx_price_array.size
# Out:
# (594677.118387189, 2793309.3338986184, 6994)

# %%
df.groupby('BOROUGH').agg({'SALE PRICE': [np.mean, np.std, np.size]})
# Out:
#            SALE PRICE
#                  mean           std     size
# BOROUGH
# 1        3.344642e+06  2.414048e+07  18102.0
# 2        5.946771e+05  2.793509e+06   6994.0
# 3        8.410834e+05  3.951912e+06  23843.0
# 4        7.388827e+05  3.227420e+06  26548.0
# 5        5.436113e+05  1.905544e+06   8296.0

# %%
mean_bronx_sale_price = 594677.118387189
std_bronx_sale_price = 2793309.3338986184
n_bronx = 6994
z=1.96

stderr_mean_bronx = std_bronx_sale_price / np.sqrt(n_bronx)
print('standard error of mean:', stderr_mean_bronx)
# Out:
# standard error of mean: 33400.749981830464

# %%
def compute_confint(estimate, stderr, z_score=1.96):
    return(
        estimate - z_score*stderr,
        estimate + z_score*stderr
    )

# %%
lower_ci, upper_ci = compute_confint(estimate=mean_bronx_sale_price, stderr=stderr_mean_bronx)

print('CI of mean estimate:[{}, {}]'.format(lower_ci, upper_ci))
# Out:
# CI of mean estimate:[529211.6484228013, 660142.5883515767]

# %% [markdown]
# ## Statistical Hypothesis Test

# %%
stat, p = shapiro(bronx_price_array)
print('stat= %.3f, p= %.3f' %(stat,p))
if p>0.05:
    print('Probably Gaussian')
else:
    print('Probably NOT Gaussian')
# Out:
# stat= 0.135, p= 0.000
# Probably NOT Gaussian
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
stat, p = normaltest(bronx_price_array)
print('stat= %.3f, p= %.3f' %(stat,p))
if p>0.05:
    print('Probably Gaussian')
else:
    print('Probably NOT Gaussian')
# Out:
# stat= 15933.166, p= 0.000
# Probably NOT Gaussian

# %% [markdown]
# ### Based on Shapiro-Wilk and D'Agostino K^2 Test, the sale price in Bronx doesn't have Gaussian/Normal Distribution as proved by the probability mass function plot above

# %% [markdown]
# ### Null hypothesis: Sale price mean value in Bronx is around 600,000

# %%
ztest, pval = wmtests.ztest(bronx_price_array, x2=None, value=600000)
print(float(pval))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.8733909701225353
# accept null hypothesis

# %% [markdown]
# ### Final conclusion: Sale price mean value in Bronx is 594,677 to be precise. So our initial hypothesis is correct!
